# %%
#to learn quandl website or python library which is a databse of dataset
#to access databset from quandl website online through API key or python link on quandl website

#parsing JSON dataset in python
import quandl
dataset=quandl.get("NSE/TCS", authtoken="FXeZpDiyM36xyyvtSjHm")
print(dataset)
# Out:
#                Open     High      Low     Last    Close  Total Trade Quantity  \
# Date
# 2004-08-25  1198.70  1198.70   979.00   985.00   987.95            17116372.0
# 2004-08-26   992.00   997.00   975.30   976.85   979.00             5055400.0
# 2004-08-27   982.40   982.40   958.55   961.20   962.65             3830750.0
# 2004-08-30   969.90   990.00   965.00   986.40   986.75             3058151.0
# 2004-08-31   986.50   990.00   976.00   987.80   988.10             2649332.0
# 2004-09-01   990.00   995.00   983.60   986.00   987.90             2491943.0
# 2004-09-02   989.90  1004.60   986.00   994.00   993.65             2669544.0
# 2004-09-03  1006.00  1100.00   990.35   998.70   997.85             1233732.0
# 2004-09-06  1039.90  1039.90   992.90   996.80   994.85             1129834.0
# 2004-09-07  1035.00  1035.00   995.00   995.00   995.60              721529.0
# 2004-09-08   996.00  1000.80   991.10   992.25   993.70              824248.0
# ...

# %%
dataset["Open"]
# Out:
# Date
# 2004-08-25    1198.70
# 2004-08-26     992.00
# 2004-08-27     982.40
# 2004-08-30     969.90
# 2004-08-31     986.50
# 2004-09-01     990.00
# 2004-09-02     989.90
# 2004-09-03    1006.00
# 2004-09-06    1039.90
# 2004-09-07    1035.00
# 2004-09-08     996.00
# 2004-09-09     997.00
# 2004-09-10     990.00
# 2004-09-13     991.00
# 2004-09-14    1005.00
# 2004-09-15    1018.00
# 2004-09-16    1007.00
# 2004-09-17    1012.00
# 2004-09-20    1032.40
# 2004-09-21    1024.85
# 2004-09-22    1048.40
# 2004-09-23    1048.00
# 2004-09-24    1029.10
# 2004-09-27    1027.50
# 2004-09-28    1016.00
# 2004-09-29    1019.25
# 2004-09-30    1035.60
# 2004-10-01    1029.00
# 2004-10-04    1057.00
# 2004-10-05    1080.30
#                ...
# 2018-01-17    2870.00
# 2018-01-18    2897.00
# 2018-01-19    2930.55
# 2018-01-22    2961.00
# 2018-01-23    3114.95
# 2018-01-24    3090.00
# 2018-01-25    3175.00
# 2018-01-29    3131.40
# 2018-01-30    3180.00
# 2018-01-31    3137.00
# ...

# %%
dataset
# Out:
#                Open     High      Low     Last    Close  Total Trade Quantity  \
# Date
# 2004-08-25  1198.70  1198.70   979.00   985.00   987.95            17116372.0
# 2004-08-26   992.00   997.00   975.30   976.85   979.00             5055400.0
# 2004-08-27   982.40   982.40   958.55   961.20   962.65             3830750.0
# 2004-08-30   969.90   990.00   965.00   986.40   986.75             3058151.0
# 2004-08-31   986.50   990.00   976.00   987.80   988.10             2649332.0
# 2004-09-01   990.00   995.00   983.60   986.00   987.90             2491943.0
# 2004-09-02   989.90  1004.60   986.00   994.00   993.65             2669544.0
# 2004-09-03  1006.00  1100.00   990.35   998.70   997.85             1233732.0
# 2004-09-06  1039.90  1039.90   992.90   996.80   994.85             1129834.0
# 2004-09-07  1035.00  1035.00   995.00   995.00   995.60              721529.0
# 2004-09-08   996.00  1000.80   991.10   992.25   993.70              824248.0
# ...

# %%
dataset["Open"][0:5]
# Out:
# Date
# 2004-08-25    1198.7
# 2004-08-26     992.0
# 2004-08-27     982.4
# 2004-08-30     969.9
# 2004-08-31     986.5
# Name: Open, dtype: float64

# %%
dataset['Total Trade Quantity'][5:20]
# Out:
# Date
# 2004-09-01    2491943.0
# 2004-09-02    2669544.0
# 2004-09-03    1233732.0
# 2004-09-06    1129834.0
# 2004-09-07     721529.0
# 2004-09-08     824248.0
# 2004-09-09     993398.0
# 2004-09-10     801884.0
# 2004-09-13    2613114.0
# 2004-09-14    1916934.0
# 2004-09-15    1498536.0
# 2004-09-16     919778.0
# 2004-09-17    1828487.0
# 2004-09-20    1069028.0
# 2004-09-21    1737135.0
# Name: Total Trade Quantity, dtype: float64

# %%
#json dataset

import json
myjson='''{
    "status":"okkk",
    "source":"datset",
    "value":"uid"
}'''
a=json.loads(myjson)
print(a)
# Out:
# {'status': 'okkk', 'source': 'datset', 'value': 'uid'}

# %%
#to ccess news data through news api
#to read json data by using news api url
import urllib.request as xyz
import json
rawdata1=xyz.urlopen("https://newsapi.org/v2/top-headlines?sources=bbc-news&apiKey=2f7ea4d0bd69421cb10f03a8e374bd9b")
print(rawdata1.read())
# Out:
# b'{"status":"ok","totalResults":10,"articles":[{"source":{"id":"bbc-news","name":"BBC News"},"author":"BBC News","title":"China \'won\'t sit by\' in Trump trade war","description":"The warning comes after Donald Trump announced steel tariffs and said that trade wars were good.","url":"http://www.bbc.co.uk/news/world-asia-china-43278458","urlToImage":"https://ichef.bbci.co.uk/images/ic/1024x576/p05zsnw9.jpg","publishedAt":"2018-03-04T12:54:17Z"},{"source":{"id":"bbc-news","name":"BBC News"},"author":"BBC News","title":"Aid plea for thousands after PNG quake","description":"Aid agencies struggle to reach isolated areas in Papua New Guinea, nearly a week after a large quake.","url":"http://www.bbc.co.uk/news/world-asia-43277013","urlToImage":"https://ichef.bbci.co.uk/news/1024/branded_news/12C4C/production/_100267867_hi045188452.jpg","publishedAt":"2018-03-04T12:34:26Z"},{"source":{"id":"bbc-news","name":"BBC News"},"author":"BBC News","title":"Oscars 2018: What to expect this year","de
# ...

# %%
import urllib.request as url
import json
rawdata1=url.urlopen("https://newsapi.org/v2/top-headlines?sources=bbc-news&apiKey=2f7ea4d0bd69421cb10f03a8e374bd9b")
#print(rawdata1.read())
myjson=rawdata1.read()
a=json.loads(myjson.decode())
#print(a)
#to access only 1st title of articles
print(a["articles"][0]["title"])
# Out:
# China 'won't sit by' in Trump trade war

# %%
import urllib.request as url
import json
rawdata1=url.urlopen("https://newsapi.org/v2/top-headlines?sources=bbc-news&apiKey=2f7ea4d0bd69421cb10f03a8e374bd9b")
#print(rawdata1.read())
myjson=rawdata1.read()
a=json.loads(myjson.decode())
#print(a)
#to access only all title of articles using for loop
for i in range(0,10):
    print(a["articles"][i]["title"])
# Out:
# China 'won't sit by' in Trump trade war
# Aid plea for thousands after PNG quake
# Oscars 2018: What to expect this year
# Residents flee Syria enclave bombardment
# Sir Roger Bannister: First man to run a mile in under four minutes dies at 88
# Davide Astori: Fiorentina captain and Italy international dies at the age of 31
# Trump skewers aides in joke-filled speech
# Mexico police 'linked to missing Italians'
# Italy to vote after divisive campaign
# Meet the real-life Three Billboards mum

# %%
import urllib.request as url
import json
rawdata1=url.urlopen("https://newsapi.org/v2/top-headlines?sources=bbc-news&apiKey=2f7ea4d0bd69421cb10f03a8e374bd9b")
#print(rawdata1.read())
myjson=rawdata1.read()
a=json.loads(myjson.decode())
#print(a)
#to access only all title of articles using for loop

#print(a["articles"])


# to access author data of articles
# for i in range(0,10):
#     print("author of articles " +str(i)+ " is")
#     print(a["articles"][i]["author"])

    
    
#     # to access description data of articles
# for i in range(0,10):
#     print(str(i+1) + "." + "description of article is "+str(i) + " is")
#     print(a["articles"][i]["description"])

    






#print(a["articles"][0])
# Out:
# {'source': {'id': 'bbc-news', 'name': 'BBC News'}, 'author': 'BBC News', 'title': "China 'won't sit by' in Trump trade war", 'description': 'The warning comes after Donald Trump announced steel tariffs and said that trade wars were good.', 'url': 'http://www.bbc.co.uk/news/world-asia-china-43278458', 'urlToImage': 'https://ichef.bbci.co.uk/images/ic/1024x576/p05zsnw9.jpg', 'publishedAt': '2018-03-04T12:54:17Z'}
