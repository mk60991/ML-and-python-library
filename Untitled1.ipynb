# %%
import numpy as np
import pandas as pd

df1=pd.DataFrame(np.random.randn(4,5),index=["row1","row2","row3","row4"],columns=["col1","col2","col3","col4","col5"])
                                                                                   

print(df1)
# Out:
#           col1      col2      col3      col4      col5
# row1  0.230780  0.318331 -0.142107 -0.002680  0.573069
# row2 -1.381100 -0.024823  1.005683 -0.717891  0.678814
# row3  0.898339 -1.544303 -1.202389  0.381756  0.728910
# row4 -0.652213  0.461346  0.926585  0.984001  1.262922

# %%
df1.iloc[0:,1:]
# Out:
#           col2      col3      col4      col5
# row1  0.318331 -0.142107 -0.002680  0.573069
# row2 -0.024823  1.005683 -0.717891  0.678814
# row3 -1.544303 -1.202389  0.381756  0.728910
# row4  0.461346  0.926585  0.984001  1.262922

# %%
df1.iloc[2,1:]
# Out:
# col2   -1.544303
# col3   -1.202389
# col4    0.381756
# col5    0.728910
# Name: row3, dtype: float64

# %%
df1.loc[["row1","row2"],["col4","col5"]]
# Out:
#           col4      col5
# row1 -0.002680  0.573069
# row2 -0.717891  0.678814

# %% [markdown]
# df1<.2

# %%
df1<.2
# Out:
#        col1   col2   col3   col4   col5
# row1  False  False   True   True  False
# row2   True   True  False   True  False
# row3  False   True   True  False  False
# row4   True  False  False  False  False

# %%
 df1["row2":"row4"]
# Out:
#           col1      col2      col3      col4      col5
# row2 -1.381100 -0.024823  1.005683 -0.717891  0.678814
# row3  0.898339 -1.544303 -1.202389  0.381756  0.728910
# row4 -0.652213  0.461346  0.926585  0.984001  1.262922

# %%
df1[:,:]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-9fd95c0ae881> in <module>()
# ----> 1 df1[:,:]
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    1962             return self._getitem_multilevel(key)
#    1963         else:
# -> 1964             return self._getitem_column(key)
#    1965
#    1966     def _getitem_column(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    1969         # get column
#    1970         if self.columns.is_unique:
# -> 1971             return self._get_item_cache(key)
#    1972
#    1973         # duplicate columns & possible reduce dimensionality
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1641         """Return the cached item, item represents a label indexer."""
# ...

# %%
df1
# Out:
#           col1      col2      col3      col4      col5
# row1  0.230780  0.318331 -0.142107 -0.002680  0.573069
# row2 -1.381100 -0.024823  1.005683 -0.717891  0.678814
# row3  0.898339 -1.544303 -1.202389  0.381756  0.728910
# row4 -0.652213  0.461346  0.926585  0.984001  1.262922

# %%
df1.iloc[1:3,0]=np.nan
df1
# Out:
#           col1      col2      col3      col4      col5
# row1  0.230780  0.318331 -0.142107 -0.002680  0.573069
# row2       NaN -0.024823  1.005683 -0.717891  0.678814
# row3       NaN -1.544303 -1.202389  0.381756  0.728910
# row4 -0.652213  0.461346  0.926585  0.984001  1.262922

# %%
df1.iloc[3,1]=np.nan
df1
# Out:
#           col1      col2      col3      col4      col5
# row1  0.230780  0.318331 -0.142107 -0.002680  0.573069
# row2       NaN -0.024823  1.005683 -0.717891  0.678814
# row3       NaN -1.544303 -1.202389  0.381756  0.728910
# row4 -0.652213       NaN  0.926585  0.984001  1.262922

# %%
df1.iloc[0:2,3]=np.nan
df1
# Out:
#           col1      col2      col3      col4      col5
# row1  0.230780  0.318331 -0.142107       NaN  0.573069
# row2       NaN -0.024823  1.005683       NaN  0.678814
# row3       NaN -1.544303 -1.202389  0.381756  0.728910
# row4 -0.652213       NaN  0.926585  0.984001  1.262922

# %%
df1.iloc[3,4]=np.nan
df1
# Out:
#           col1      col2      col3      col4      col5
# row1  0.230780  0.318331 -0.142107       NaN  0.573069
# row2       NaN -0.024823  1.005683       NaN  0.678814
# row3       NaN -1.544303 -1.202389  0.381756  0.728910
# row4 -0.652213       NaN  0.926585  0.984001       NaN

# %%
df1.iloc[0:2,2]=["mk","ish"]
df1
# Out:
#           col1      col2      col3      col4      col5
# row1  0.230780  0.318331        mk       NaN  0.573069
# row2       NaN -0.024823       ish       NaN  0.678814
# row3       NaN -1.544303  -1.20239  0.381756  0.728910
# row4 -0.652213       NaN  0.926585  0.984001       NaN

# %%
df1.iloc[0,1]="roy"
df1
# Out:
#           col1       col2      col3      col4      col5
# row1  0.230780        roy        mk       NaN  0.573069
# row2       NaN -0.0248229       ish       NaN  0.678814
# row3       NaN    -1.5443  -1.20239  0.381756  0.728910
# row4 -0.652213        NaN  0.926585  0.984001       NaN

# %%
df2=df1.fillna({"NaN":0.1,"mk":1.25})
df2
# Out:
#           col1       col2      col3      col4      col5
# row1  0.230780        roy        mk       NaN  0.573069
# row2       NaN -0.0248229       ish       NaN  0.678814
# row3       NaN    -1.5443  -1.20239  0.381756  0.728910
# row4 -0.652213        NaN  0.926585  0.984001       NaN

# %%
df2=df1.fillna(0)
df2
# Out:
#           col1       col2      col3      col4      col5
# row1  0.230780        roy        mk  0.000000  0.573069
# row2  0.000000 -0.0248229       ish  0.000000  0.678814
# row3  0.000000    -1.5443  -1.20239  0.381756  0.728910
# row4 -0.652213          0  0.926585  0.984001  0.000000

# %%
df2=df1.fillna({0:1,1:2,4:3,5:4})
df2
# Out:
#           col1       col2      col3      col4      col5
# row1  0.230780        roy        mk       NaN  0.573069
# row2       NaN -0.0248229       ish       NaN  0.678814
# row3       NaN    -1.5443  -1.20239  0.381756  0.728910
# row4 -0.652213        NaN  0.926585  0.984001       NaN

# %%
df1
# Out:
#           col1       col2      col3      col4      col5
# row1  0.230780        roy        mk       NaN  0.573069
# row2       NaN -0.0248229       ish       NaN  0.678814
# row3       NaN    -1.5443  -1.20239  0.381756  0.728910
# row4 -0.652213        NaN  0.926585  0.984001       NaN

# %%
#count missing value in dataset

df1.isnull().sum()
# Out:
# col1    2
# col2    1
# col3    0
# col4    2
# col5    1
# dtype: int64

# %%
df3=df1.dropna(axis=1)
df3
# Out:
#           col3
# row1        mk
# row2       ish
# row3  -1.20239
# row4  0.926585

# %%
df1
# Out:
#           col1       col2      col3      col4      col5
# row1  0.230780        roy        mk       NaN  0.573069
# row2       NaN -0.0248229       ish       NaN  0.678814
# row3       NaN    -1.5443  -1.20239  0.381756  0.728910
# row4 -0.652213        NaN  0.926585  0.984001       NaN

# %%
df4=df1.dropna(axis=0)
df4
# Out:
# Empty DataFrame
# Columns: [col1, col2, col3, col4, col5]
# Index: []

# %%
df5=df1.dropna(how="all")
df5
# Out:
#           col1       col2      col3      col4      col5
# row1  0.230780        roy        mk       NaN  0.573069
# row2       NaN -0.0248229       ish       NaN  0.678814
# row3       NaN    -1.5443  -1.20239  0.381756  0.728910
# row4 -0.652213        NaN  0.926585  0.984001       NaN

# %%
df1
# Out:
#           col1       col2      col3      col4      col5
# row1  0.230780        roy        mk       NaN  0.573069
# row2       NaN -0.0248229       ish       NaN  0.678814
# row3       NaN    -1.5443  -1.20239  0.381756  0.728910
# row4 -0.652213        NaN  0.926585  0.984001       NaN

# %%
dfx=pd.DataFrame(np.arange(16).reshape(4,4),index=["row1","row2","row3","row4"],columns=["col1","col2","col3","col4"])
dfx
# Out:
#       col1  col2  col3  col4
# row1     0     1     2     3
# row2     4     5     6     7
# row3     8     9    10    11
# row4    12    13    14    15
